# %% [markdown]
# ## 578hw3-initial.ipynb
# #### Run all cells in this file with the original "NN578_network.py" to ensure the code runs on your platform.

# %% [markdown]
# <b>NOTE</b>: This is a version for Google CoLab. <br>
# If you make changes to the .py file (which you are importing), you must restart the kernel and run the code again.  To do so you select **'Runtime'** and **'Restart and run all..'**

# %%
## Code piece to mount my Google Drive
from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# See the list of files in this local folder (the example here is 'Temp')
# !ls -l '/content/drive/MyDrive/CSC578/hw3'
# Out:
# total 1309
# -rw------- 1 root root 278091 Apr 20 13:38  578hw3-checktestset.html
# -rw------- 1 root root   2444 Apr 20 13:38  578hw3-checktestset.ipynb
# -rw------- 1 root root 273597 Apr 20 13:38  578hw3.html
# -rw------- 1 root root   9081 Apr 20 14:29  578hw3-initial-CoLab.ipynb
# -rw------- 1 root root  38599 Apr 20 13:38 '578hw3-initial-CoLab.ipynb - Colaboratory.pdf'
# -rw------- 1 root root 276175 Apr 20 13:38  578hw3-initial.html
# -rw------- 1 root root   2306 Apr 20 13:38  578hw3-initial.ipynb
# -rw------- 1 root root   1397 Apr 20 13:38  578hw3.ipynb
# -rw------- 1 root root 254714 Apr 20 13:38  Demo-NumpyIndex.html
# -rw------- 1 root root  15467 Apr 20 13:38  hw2-CE.png
# -rw------- 1 root root   4213 Apr 20 13:38  hw2-CE_small.png
# -rw------- 1 root root  14587 Apr 20 13:38  hw2-LL.png
# -rw------- 1 root root   4083 Apr 20 13:38  hw2-LL_small.png
# -rw------- 1 root root  14698 Apr 20 13:38  hw2-MSE.png
# -rw------- 1 root root   4191 Apr 20 13:38  hw2-MSE_small.png
# -rw------- 1 root root  17099 Apr 20 13:38  hw2-temp1.png
# -rw------- 1 root root   5056 Apr 20 13:38  hw2-temp1_small.png
# -rw------- 1 root root  27857 Apr 20 13:38  index.html
# -rw------- 1 root root  17584 Apr 20 13:38  index.org
# -rw------- 1 root root  17695 Apr 20 13:38  index-v1.org
# -rw------- 1 root root   1040 Apr 20 13:38  intro-vid.org
# -rw------- 1 root root   5920 Apr 20 13:38  iris4-20-7-3.dat
# -rw------- 1 root root    468 Apr 20 13:38  iris-423.dat
# -rw------- 1 root root   3301 Apr 20 13:38  iris.csv
# -rw------- 1 root root  13972 Apr 20 13:38  network2.py
# -rw------- 1 root root   8311 Apr 20 13:38  NN578_network.py
# drwx------ 2 root root   4096 Apr 20 13:58  __pycache__
# -rw------- 1 root root  10086 Apr 20 13:38  Results-1.txt
# -rw------- 1 root root   6331 Apr 20 13:38  Results-2.txt

# %%
# Change the working directory to that 'Temp' folder, in my case it is hw3
import os
os.chdir('/content/drive/MyDrive/CSC578/hw3')

# Ensure the files are there (in the 'Temp' folder)
# !ls -l
# Out:
# total 1309
# -rw------- 1 root root 278091 Apr 20 13:38  578hw3-checktestset.html
# -rw------- 1 root root   2444 Apr 20 13:38  578hw3-checktestset.ipynb
# -rw------- 1 root root 273597 Apr 20 13:38  578hw3.html
# -rw------- 1 root root   9081 Apr 20 14:29  578hw3-initial-CoLab.ipynb
# -rw------- 1 root root  38599 Apr 20 13:38 '578hw3-initial-CoLab.ipynb - Colaboratory.pdf'
# -rw------- 1 root root 276175 Apr 20 13:38  578hw3-initial.html
# -rw------- 1 root root   2306 Apr 20 13:38  578hw3-initial.ipynb
# -rw------- 1 root root   1397 Apr 20 13:38  578hw3.ipynb
# -rw------- 1 root root 254714 Apr 20 13:38  Demo-NumpyIndex.html
# -rw------- 1 root root  15467 Apr 20 13:38  hw2-CE.png
# -rw------- 1 root root   4213 Apr 20 13:38  hw2-CE_small.png
# -rw------- 1 root root  14587 Apr 20 13:38  hw2-LL.png
# -rw------- 1 root root   4083 Apr 20 13:38  hw2-LL_small.png
# -rw------- 1 root root  14698 Apr 20 13:38  hw2-MSE.png
# -rw------- 1 root root   4191 Apr 20 13:38  hw2-MSE_small.png
# -rw------- 1 root root  17099 Apr 20 13:38  hw2-temp1.png
# -rw------- 1 root root   5056 Apr 20 13:38  hw2-temp1_small.png
# -rw------- 1 root root  27857 Apr 20 13:38  index.html
# -rw------- 1 root root  17584 Apr 20 13:38  index.org
# -rw------- 1 root root  17695 Apr 20 13:38  index-v1.org
# -rw------- 1 root root   1040 Apr 20 13:38  intro-vid.org
# -rw------- 1 root root   5920 Apr 20 13:38  iris4-20-7-3.dat
# -rw------- 1 root root    468 Apr 20 13:38  iris-423.dat
# -rw------- 1 root root   3301 Apr 20 13:38  iris.csv
# -rw------- 1 root root  13972 Apr 20 13:38  network2.py
# -rw------- 1 root root   8311 Apr 20 13:38  NN578_network.py
# drwx------ 2 root root   4096 Apr 20 13:58  __pycache__
# -rw------- 1 root root  10086 Apr 20 13:38  Results-1.txt
# -rw------- 1 root root   6331 Apr 20 13:38  Results-2.txt

# %%
#import NN578_network as network
#import numpy as np
net = Network(['iris.csv', 4, 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-d9ec05041fc9> in <module>()
#       1 #import NN578_network as network
#       2 #import numpy as np
# ----> 3 net = Network(['iris.csv', 4, 3])
#
# <ipython-input-31-a0a319d35fea> in __init__(self, sizes)
#      34         self.sizes = sizes
#      35         self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
# ---> 36         self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
#      37
#      38     def feedforward(self, a):
#
# <ipython-input-31-a0a319d35fea> in <listcomp>(.0)
#      34         self.sizes = sizes
#      35         self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
# ---> 36         self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
#      37
#      38     def feedforward(self, a):
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randn()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.standard_normal()
#
# _common.pyx in numpy.random._common.cont()
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
# Load the dataset (already in the 'one-hot-vector' format for the target)
# Call the function to load the data.
iris_data = network.my_load_csv('iris.csv', 4, 3)
# Out:
# /content/drive/MyDrive/CSC578/hw3/NN578_network.py:203: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   [(entry[:no_trainfeatures], entry[no_trainfeatures:]) for entry in ret]

# %%
# Create a network from the saved network
net1 = network.load_network("iris-423.dat")

# Train the network for 2 epochs, with minibatch size 10, eta=0.7 and no testset.
# Note the original function SGD does not return anything, so no attempt is made
# to receive the returned value. 
net1.SGD(iris_data, 2, 10, 0.7)
# Out:
# Epoch 0 complete
# Epoch 1 complete

# %%
# re-load the saved network and run it again this time with the test data 
# (though the same dataset, just to check).
net2 = network.load_network("iris-423.dat")
net2.SGD(iris_data, 2, 10, 0.7, iris_data)
# Out:
# Epoch 0: 50 / 150
# Epoch 1: 50 / 150
