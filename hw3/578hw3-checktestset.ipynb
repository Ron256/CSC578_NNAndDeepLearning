# %%
# Code piece to mount my Google Drive
from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# See the list of files in this local folder (the example here is 'Temp')
# !ls -l '/content/drive/MyDrive/CSC578/hw3'
# Out:
# total 1552
# -rw------- 1 root root 278091 Apr 20 13:38  578hw3-checktestset.html
# -rw------- 1 root root   7188 Apr 24 16:39  578hw3-checktestset.ipynb
# -rw------- 1 root root 273597 Apr 20 13:38  578hw3.html
# -rw------- 1 root root  15266 Apr 21 04:44  578hw3-initial-CoLab.ipynb
# -rw------- 1 root root  38599 Apr 20 13:38 '578hw3-initial-CoLab.ipynb - Colaboratory.pdf'
# -rw------- 1 root root 276175 Apr 20 13:38  578hw3-initial.html
# -rw------- 1 root root   2106 Apr 22 16:57  578hw3-initial.ipynb
# -rw------- 1 root root 226525 Apr 24 17:12  578hw3.ipynb
# -rw------- 1 root root 254714 Apr 20 13:38  Demo-NumpyIndex.html
# -rw------- 1 root root  15467 Apr 20 13:38  hw2-CE.png
# -rw------- 1 root root   4213 Apr 20 13:38  hw2-CE_small.png
# -rw------- 1 root root  14587 Apr 20 13:38  hw2-LL.png
# -rw------- 1 root root   4083 Apr 20 13:38  hw2-LL_small.png
# -rw------- 1 root root  14698 Apr 20 13:38  hw2-MSE.png
# -rw------- 1 root root   4191 Apr 20 13:38  hw2-MSE_small.png
# -rw------- 1 root root  17099 Apr 20 13:38  hw2-temp1.png
# -rw------- 1 root root   5056 Apr 20 13:38  hw2-temp1_small.png
# -rw------- 1 root root  27857 Apr 20 13:38  index.html
# -rw------- 1 root root  17584 Apr 20 13:38  index.org
# -rw------- 1 root root  17695 Apr 20 13:38  index-v1.org
# -rw------- 1 root root   1040 Apr 20 13:38  intro-vid.org
# -rw------- 1 root root   5920 Apr 20 13:38  iris4-20-7-3.dat
# -rw------- 1 root root    468 Apr 20 13:38  iris-423.dat
# -rw------- 1 root root   3301 Apr 20 13:38  iris.csv
# -rw------- 1 root root  13972 Apr 20 13:38  network2.py
# -rw------- 1 root root  12498 Apr 24 16:35  NN578_network_cp.py
# -rw------- 1 root root   8311 Apr 20 13:38  NN578_network.py
# drwx------ 2 root root   4096 Apr 24 16:35  __pycache__
# -rw------- 1 root root  10086 Apr 20 13:38  Results-1.txt
# -rw------- 1 root root   6331 Apr 20 13:38  Results-2.txt

# %%
# Change the working directory to hw3
import os
os.chdir('/content/drive/MyDrive/CSC578/hw3')

# %%
import NN578_network_cp as network
import numpy as np

# %%
# %cat iris-423.dat
# Out:
# {"sizes": [4, 2, 3], "weights": [[[1.4440214578696242, -1.071479276360782, 0.6064662081510545, 1.6623324193643565], [0.17762761083498946, -0.07016733744979953, -1.6953554109705309, -1.8491508210692411]], [[1.1407956679681293, -0.14930208222236388], [1.1902069564053663, 0.2156475880844977], [-0.5451392275471726, -0.6784576924988164]]], "biases": [[[-1.771205596141514], [-0.16723078043142234]], [[-0.5551943373152782], [-0.8524865023170752], [-0.35209109499516567]]]}

# %%
net4 = network.load_network("iris-423.dat")

# Create two data instances on the fly
inst1 = (np.array([5.7, 3, 4.2, 1.2]), np.array([0., 1., 0.]))
x1 = np.reshape(inst1[0], (4, 1))
y1 = np.reshape(inst1[1], (3, 1))
sample1 = [(x1, y1)]
#print(sample1)
inst2 = (np.array([4.8, 3.4, 1.6, 0.2]), np.array([1., 0., 0.]))
x2 = np.reshape(inst2[0], (4, 1))
y2 = np.reshape(inst2[1], (3, 1))
sample2 = [(x2, y2)]
#print(sample2)

# Call SGD with one instance for training and another for testing,
#  for one epoch, with batch_size=1, and eta=1.0. 
# First with both training and test instances.
results10 = net4.SGD(sample1, 1, 1, 1.0, sample2)
print (results10)
print ()
# Then with just training instance
results11 = net4.SGD(sample1, 1, 1, 1.0)
print (results11)
# Out:
# [Epoch 0] Training: MSE=0.26673129, CE=1.61690061, LL=0.45930834, Correct: 1/1, Acc: 1.00000000
# Test: MSE=0.26673129, CE=1.61690061, LL=0.45930834, Correct: 1/1, Acc: 1.00000000
# [[[1, 1.0, 0.26673128660052947, 1.6169006088912665, 0.4593083419698332]], [[0, 0.0, 0.3244002758397572, 1.855818621521176, 0.5871219174966811]]]
#
# [Epoch 0] Training: MSE=0.21078666, CE=1.38020720, LL=0.39958448, Correct: 1/1, Acc: 1.00000000
# [[[1, 1.0, 0.2107866577006649, 1.3802072032795016, 0.39958447879106]], [[]]]
